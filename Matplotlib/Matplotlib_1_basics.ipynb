# %% [markdown]
# # Histograms, Pie Charts, and Animations

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
npts = 2500
nbins = 15

# Creating a normal distribution of data.
np.random.seed(0)
x = np.random.normal(size=npts)

# %% [markdown]
# ## Histograms

# %%
plt.hist(x, bins=nbins, density=True)
plt.title('1D histogram')
plt.xlabel('Data')
plt.ylabel('Probability')
plt.show()

# %%
y = np.random.normal(size=npts)

plt.hist2d(x, y, bins=nbins)
plt.show()

# %% [markdown]
# ## Pie Charts

# %%
x = np.array([25, 15, 20, 40])
plt.pie(x)
plt.show()

# %%
x = np.array([0.25, 0.20, 0.40])
plt.pie(x, normalize=False)
plt.show()

# %%
colors = ['red', 'blue', 'yellow', 'pink', 'green']
labels = [c.capitalize() for c in colors]

sizes = [1, 3, 5, 7, 9]
explode = (0, 0, 0, 0.1, 0)


plt.pie(sizes, labels=labels, explode=explode, colors=colors, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## Animations

# %%
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation
print(animation.writers.list())
# Out:
# ['pillow', 'html']

# %%
fig, ax = plt.subplots()
ax.set_xlim(0, 2 * np.pi)
ax.set_ylim(-1.5, 1.5)

(line,) = ax.plot([], [])


def init():
    line.set_data([], [])
    return (line,)

# %%
def animate(i):
    x = np.linspace(0, 2 * np.pi, 250)

    y = np.sin(2 * np.pi * (x - 0.1 * i))

    line.set_data(x, y)

    return (line,)

# %%
anim = FuncAnimation(fig, animate, init_func=init, frames=200, interval=20, blit=True)

# %%
from matplotlib import rc

rc('animation', html='pillow')

anim
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8368\717922760.py in <module>
#       1 from matplotlib import rc
#       2
# ----> 3 rc('animation', html='pillow')
#       4
#       5 anim
#
# c:\Users\guill\anaconda3\lib\site-packages\matplotlib\__init__.py in rc(group, **kwargs)
#     973             key = '%s.%s' % (g, name)
#     974             try:
# --> 975                 rcParams[key] = v
#     976             except KeyError as err:
#     977                 raise KeyError(('Unrecognized key "%s" for group "%s" and '
#
# c:\Users\guill\anaconda3\lib\site-packages\matplotlib\__init__.py in __setitem__(self, key, val)
#     644                 cval = self.validate[key](val)
#     645             except ValueError as ve:
# --> 646                 raise ValueError(f"Key {key}: {ve}") from None
#     647             dict.__setitem__(self, key, cval)
#     648         except KeyError as err:
#
# ValueError: Key animation.html: 'pillow' is not a valid value for animation.html; supported values are ['html5', 'jshtml', 'none']
